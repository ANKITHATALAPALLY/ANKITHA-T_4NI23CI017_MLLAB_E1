# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKITHATALAPALLY/ANKITHA-T_4NI23CI017_MLLAB_E1/blob/main/MLLAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[
    ['Sunny','hot','high','weak','no'],
    ['Sunny','hot','high','strong','yes'],
    ['overcast','hot','high','weak','yes'],
    ['rainy','mild','high','weak','yes'],
    ['rainy','cool','normal','weak','yes'],
    ['rainy','cool','normal','strong','no'],
    ['overcast','cool','normal','strong','yes'],
    ['sunny','mild','high','weak','no'],
    ['sunny','cool','normal','weak','yes'],
    ['rainy','mild','normal','weak','yes']
]
columns=['Outlook','Temperature','Humidity','wind','Playtennis']
df=pd.DataFrame(data,columns=columns)

x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
hypothesis=None
for i in range(len(x)):
    if y[i]=='yes':
      if hypothesis is None:
        hypothesis=x[i].copy()
      else:
        for j in range(len(hypothesis)):
          if hypothesis[j]!=x[i][j]:
            hypothesis[j]='?'
    print("step ",i+1,"hypothesis",hypothesis)
print(hypothesis)
# Out:
# step  1 hypothesis None
# step  2 hypothesis ['Sunny' 'hot' 'high' 'strong']
# step  3 hypothesis ['?' 'hot' 'high' '?']
# step  4 hypothesis ['?' '?' 'high' '?']
# step  5 hypothesis ['?' '?' '?' '?']
# step  6 hypothesis ['?' '?' '?' '?']
# step  7 hypothesis ['?' '?' '?' '?']
# step  8 hypothesis ['?' '?' '?' '?']
# step  9 hypothesis ['?' '?' '?' '?']
# step  10 hypothesis ['?' '?' '?' '?']
# ['?' '?' '?' '?']

# %%
import csv

def find_s(data):
    hypothesis = None

    for row in data:
        attributes = row[:-1]
        target = row[-1]

        if target.lower() == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
            else:
                for i in range(len(hypothesis)):
                    if hypothesis[i] != attributes[i]:
                        hypothesis[i] = "?"

    return hypothesis


filename = "training_data.csv"

with open('PLAY_TENNIS1.csv', "r") as file:
    reader = csv.reader(file)
    header = next(reader)
    data = list(reader)

hypothesis = find_s(data)

# %%
import csv

def find_s(data):
    hypothesis = None

    for i, row in enumerate(data, start=1):
        row = [x.strip() for x in row]
        attributes = row[:-1]
        target = row[-1].lower()

        print("\nExample", i, ":", row)

        if target == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
                print("Positive example")
                print("Initial hypothesis:", hypothesis)
            else:
                print("Positive example")
                for j in range(len(hypothesis)):
                    if hypothesis[j] != attributes[j]:
                        hypothesis[j] = "?"
                print("Updated hypothesis:", hypothesis)
        else:
            print("Negative example - ignored")

        print("Current hypothesis:", hypothesis)

    return hypothesis


filename = "PLAY_TENNIS1.csv"

with open(filename, "r") as file:
    reader = csv.reader(file)
    header = next(reader)
    data = list(reader)

print("Attributes:", header[:-1])
print("Target:", header[-1])

hypothesis = find_s(data)

print("\nFinal Hypothesis:")
print(hypothesis)
# Out:
# Attributes: ['Outlook', 'Temperature', 'Humidity', 'Windy']
# Target: PlayTennis
#
# Example 1 : ['Sunny', 'Hot', 'High', 'False', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 2 : ['Sunny', 'Hot', 'High', 'True', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 3 : ['Overcast', 'Hot', 'High', 'False', 'Yes']
# Positive example
# Initial hypothesis: ['Overcast', 'Hot', 'High', 'False']
# Current hypothesis: ['Overcast', 'Hot', 'High', 'False']
#
# Example 4 : ['Rain', 'Mild', 'High', 'False', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', 'High', 'False']
# Current hypothesis: ['?', '?', 'High', 'False']
#
# Example 5 : ['Rain', 'Cool', 'Normal', 'False', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', 'False']
# Current hypothesis: ['?', '?', '?', 'False']
#
# Example 6 : ['Rain', 'Cool', 'Normal', 'True', 'No']
# Negative example - ignored
# Current hypothesis: ['?', '?', '?', 'False']
#
# Example 7 : ['Overcast', 'Cool', 'Normal', 'True', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 8 : ['Sunny', 'Mild', 'High', 'False', 'No']
# Negative example - ignored
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 9 : ['Sunny', 'Cool', 'Normal', 'False', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 10 : ['Rain', 'Mild', 'Normal', 'False', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 11 : ['Sunny', 'Mild', 'Normal', 'True', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 12 : ['Overcast', 'Mild', 'High', 'True', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 13 : ['Overcast', 'Hot', 'Normal', 'False', 'Yes']
# Positive example
# Updated hypothesis: ['?', '?', '?', '?']
# Current hypothesis: ['?', '?', '?', '?']
#
# Example 14 : ['Rain', 'Mild', 'High', 'True', 'No']
# Negative example - ignored
# Current hypothesis: ['?', '?', '?', '?']
#
# Final Hypothesis:
# ['?', '?', '?', '?']

# %%
import csv

def find_s(data):
    hypothesis = None

    for i, row in enumerate(data, start=1):
        row = [x.strip() for x in row]
        attributes = row[:-1]
        target = row[-1].lower()

        print("\nExample", i, ":", row)

        if target == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
                print("Positive example")
                print("Initial hypothesis:", hypothesis)
            else:
                print("Positive example")
                for j in range(len(hypothesis)):
                    if hypothesis[j] != attributes[j]:
                        hypothesis[j] = "?"
                print("Updated hypothesis:", hypothesis)
        else:
            print("Negative example - ignored")

        print("Current hypothesis:", hypothesis)

    return hypothesis


filename = "car evaluation_with.csv"

with open(filename, "r") as file:
    reader = csv.reader(file)
    header = next(reader)
    data = list(reader)

print("Attributes:", header[:-1])
print("Target:", header[-1])

hypothesis = find_s(data)

print("\nFinal Hypothesis:")
print(hypothesis)
# Out:
# Attributes: ['vhigh', 'vhigh', '2', '2', 'small', 'med']
# Target: unacc
#
# Example 1 : ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 2 : ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 3 : ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 4 : ['vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 5 : ['vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 6 : ['vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 7 : ['vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 8 : ['vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 9 : ['vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 10 : ['vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 11 : ['vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 12 : ['vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 13 : ['vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 14 : ['vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 15 : ['vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 16 : ['vhigh', 'vhigh', '2', '4', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 17 : ['vhigh', 'vhigh', '2', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 18 : ['vhigh', 'vhigh', '2', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 19 : ['vhigh', 'vhigh', '2', '5', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 20 : ['vhigh', 'vhigh', '2', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example
'5', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 161 : ['vhigh', 'high', '4', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 162 : ['vhigh', 'high', '4', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 163 : ['vhigh', 'high', '4', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 164 : ['vhigh', 'high', '4', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 165 : ['vhigh', 'high', '4', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 166 : ['vhigh', 'high', '4', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 167 : ['vhigh', 'high', '4', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 168 : ['vhigh', 'high', '4', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 169 : ['vhigh', 'high', '4', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 170 : ['vhigh', 'high', '4', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 171 : ['vhigh', 'high', '4', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 172 : ['vhigh', 'high', '4', '4', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 173 : ['vhigh', 'high', '4', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 174 : ['vhigh', 'high', '4', '4', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 175 : ['vhigh', 'high', '4', '4', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 176 : ['vhigh', 'high', '4', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 177 : ['vhigh', 'high', '4', '4', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 178 : ['vhigh', 'high', '4', '4', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 179 : ['vhigh', 'high', '4', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 180 : ['vhigh', 'high', '4', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 181 : ['vhigh', 'high', '4', '5', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 182 : ['vhigh', 'high', '4', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 183 : ['vhigh', 'high', '4', '5', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 184 : ['vhigh', 'high', '4', '5', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 185 : ['vhigh', 'high', '4', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 186 : ['vhigh', 'high', '4', '5', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 187 : ['vhigh', 'high', '4', '5', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 188 : ['vhigh', 'high', '5', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 189 : ['vhigh', 'high', '5', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 190 : ['vhigh', 'high', '5', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 191 : ['vhigh', 'high', '5', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 192 : ['vhigh', 'high', '5', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 193 : ['vhigh', 'high', '5', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 194 : ['vhigh', 'high', '5', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 195 : ['vhigh', 'high', '5', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 196 : ['vhigh', 'high', '5', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 197 : ['vhigh', 'high', '5', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 198 : ['vhigh', 'high', '5', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 199 : ['vhigh', 'high', '5', '4', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 200 : ['vhigh', 'high', '5', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 201 : ['vhigh', 'high', '5', '4', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 202 : ['vhigh', 'high', '5', '4', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 203 : ['vhigh', 'high', '5', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 204 : ['vhigh', 'high', '5', '4', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 205 : ['vhigh', 'high', '5', '4', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 206 : ['vhigh', 'high', '5', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 207 : ['vhigh', 'high', '5', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 208 : ['vhigh', 'high', '5', '5', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 209 : ['vhigh', 'high', '5', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 210 : ['vhigh', 'high', '5', '5', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 211 : ['vhigh', 'high', '5', '5', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 212 : ['vhigh', 'high', '5', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 213 : ['vhigh', 'high', '5', '5', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 214 : ['vhigh', 'high', '5', '5', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 215 : ['vhigh', 'med', '2', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 216 : ['vhigh', 'med', '2', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 217 : ['vhigh', 'med', '2', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 218 : ['vhigh', 'med', '2', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 219 : ['vhigh', 'med', '2', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 220 : ['vhigh', 'med', '2', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 221 : ['vhigh', 'med', '2', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 222 : ['vhigh', 'med', '2', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 223 : ['vhigh', 'med', '2', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 224 : ['vhigh', 'med', '2', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 225 : ['vhigh', 'med', '2', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 226 : ['vhigh', 'med', '2', '4', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 227 : ['vhigh', 'med', '2', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 228 : ['vhigh', 'med', '2', '4', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 229 : ['vhigh', 'med', '2', '4', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 230 : ['vhigh', 'med', '2', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 231 : ['vhigh', 'med', '2', '4', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 232 : ['vhigh', 'med', '2', '4', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 233 : ['vhigh', 'med', '2', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 234 : ['vhigh', 'med', '2', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 235 : ['vhigh', 'med', '2', '5', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 236 : ['vhigh', 'med', '2', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 237 : ['vhigh', 'med', '2', '5', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 238 : ['vhigh', 'med', '2', '5', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 239 : ['vhigh', 'med', '2', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 240 : ['vhigh', 'med', '2', '5', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 241 : ['vhigh', 'med', '2', '5', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 242 : ['vhigh', 'med', '3', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 243 : ['vhigh', 'med', '3', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 244 : ['vhigh', 'med', '3', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 245 : ['vhigh', 'med', '3', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 246 : ['vhigh', 'med', '3', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 247 : ['vhigh', 'med', '3', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 248 : ['vhigh', 'med', '3', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 249 : ['vhigh', 'med', '3', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 250 : ['vhigh', 'med', '3', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 251 : ['vhigh', 'med', '3', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 252 : ['vhigh', 'med', '3', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 253 : ['vhigh', 'med', '3', '4', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 254 : ['vhigh', 'med', '3', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 255 : ['vhigh', 'med', '3', '4', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 256 : ['vhigh', 'med', '3', '4', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 257 : ['vhigh', 'med', '3', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 258 : ['vhigh', 'med', '3', '4', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 259 : ['vhigh', 'med', '3', '4', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 260 : ['vhigh', 'med', '3', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 261 : ['vhigh', 'med', '3', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 262 : ['vhigh', 'med', '3', '5', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 263 : ['vhigh', 'med', '3', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 264 : ['vhigh', 'med', '3', '5', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 265 : ['vhigh', 'med', '3', '5', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 266 : ['vhigh', 'med', '3', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 267 : ['vhigh', 'med', '3', '5', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 268 : ['vhigh', 'med', '3', '5', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 269 : ['vhigh', 'med', '4', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 270 : ['vhigh', 'med', '4', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 271 : ['vhigh', 'med', '4', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 272 : ['vhigh', 'med', '4', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 273 : ['vhigh', 'med', '4', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 274 : ['vhigh', 'med', '4', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 275 : ['vhigh', 'med', '4', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 276 : ['vhigh', 'med', '4', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 277 : ['vhigh', 'med', '4', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 278 : ['vhigh', 'med', '4', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 279 : ['vhigh', 'med', '4', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 280 : ['vhigh', 'med', '4', '4', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 281 : ['vhigh', 'med', '4', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 282 : ['vhigh', 'med', '4', '4', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 283 : ['vhigh', 'med', '4', '4', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 284 : ['vhigh', 'med', '4', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 285 : ['vhigh', 'med', '4', '4', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 286 : ['vhigh', 'med', '4', '4', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 287 : ['vhigh', 'med', '4', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 288 : ['vhigh', 'med', '4', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 289 : ['vhigh', 'med', '4', '5', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 290 : ['vhigh', 'med', '4', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 291 : ['vhigh', 'med', '4', '5', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 292 : ['vhigh', 'med', '4', '5', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 293 : ['vhigh', 'med', '4', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 294 : ['vhigh', 'med', '4', '5', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 295 : ['vhigh', 'med', '4', '5', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 296 : ['vhigh', 'med', '5', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 297 : ['vhigh', 'med', '5', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 298 : ['vhigh', 'med', '5', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 299 : ['vhigh', 'med', '5', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 300 : ['vhigh', 'med', '5', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 301 : ['vhigh', 'med', '5', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 302 : ['vhigh', 'med', '5', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 303 : ['vhigh', 'med', '5', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 304 : ['vhigh', 'med', '5', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 305 : ['vhigh', 'med', '5', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 306 : ['vhigh', 'med', '5', '4', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 307 : ['vhigh', 'med', '5', '4', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 308 : ['vhigh', 'med', '5', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 309 : ['vhigh', 'med', '5', '4', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 310 : ['vhigh', 'med', '5', '4', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 311 : ['vhigh', 'med', '5', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 312 : ['vhigh', 'med', '5', '4', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 313 : ['vhigh', 'med', '5', '4', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example
'4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 390 : ['vhigh', 'low', '4', '4', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 391 : ['vhigh', 'low', '4', '4', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 392 : ['vhigh', 'low', '4', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 393 : ['vhigh', 'low', '4', '4', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 394 : ['vhigh', 'low', '4', '4', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 395 : ['vhigh', 'low', '4', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 396 : ['vhigh', 'low', '4', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 397 : ['vhigh', 'low', '4', '5', 'small', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 398 : ['vhigh', 'low', '4', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 399 : ['vhigh', 'low', '4', '5', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 400 : ['vhigh', 'low', '4', '5', 'med', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 401 : ['vhigh', 'low', '4', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 402 : ['vhigh', 'low', '4', '5', 'big', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 403 : ['vhigh', 'low', '4', '5', 'big', 'high', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 404 : ['vhigh', 'low', '5', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 405 : ['vhigh', 'low', '5', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# ...
#
# Example 1590 : ['low', 'med', '4', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1591 : ['low', 'med', '4', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1592 : ['low', 'med', '5', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1593 : ['low', 'med', '5', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1594 : ['low', 'med', '5', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1595 : ['low', 'med', '5', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1596 : ['low', 'med', '5', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1597 : ['low', 'med', '5', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1598 : ['low', 'med', '5', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1599 : ['low', 'med', '5', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1600 : ['low', 'med', '5', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1601 : ['low', 'med', '5', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1602 : ['low', 'med', '5', '4', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1603 : ['low', 'med', '5', '4', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1604 : ['low', 'med', '5', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1605 : ['low', 'med', '5', '4', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1606 : ['low', 'med', '5', '4', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1607 : ['low', 'med', '5', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1608 : ['low', 'med', '5', '4', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1609 : ['low', 'med', '5', '4', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1610 : ['low', 'med', '5', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1611 : ['low', 'med', '5', '5', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1612 : ['low', 'med', '5', '5', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1613 : ['low', 'med', '5', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1614 : ['low', 'med', '5', '5', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1615 : ['low', 'med', '5', '5', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1616 : ['low', 'med', '5', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1617 : ['low', 'med', '5', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1618 : ['low', 'med', '5', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1619 : ['low', 'low', '2', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1620 : ['low', 'low', '2', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1621 : ['low', 'low', '2', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1622 : ['low', 'low', '2', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1623 : ['low', 'low', '2', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1624 : ['low', 'low', '2', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1625 : ['low', 'low', '2', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1626 : ['low', 'low', '2', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1627 : ['low', 'low', '2', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1628 : ['low', 'low', '2', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1629 : ['low', 'low', '2', '4', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1630 : ['low', 'low', '2', '4', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1631 : ['low', 'low', '2', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1632 : ['low', 'low', '2', '4', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1633 : ['low', 'low', '2', '4', 'med', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1634 : ['low', 'low', '2', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1635 : ['low', 'low', '2', '4', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1636 : ['low', 'low', '2', '4', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1637 : ['low', 'low', '2', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1638 : ['low', 'low', '2', '5', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1639 : ['low', 'low', '2', '5', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1640 : ['low', 'low', '2', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1641 : ['low', 'low', '2', '5', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1642 : ['low', 'low', '2', '5', 'med', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1643 : ['low', 'low', '2', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1644 : ['low', 'low', '2', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1645 : ['low', 'low', '2', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1646 : ['low', 'low', '3', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1647 : ['low', 'low', '3', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1648 : ['low', 'low', '3', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1649 : ['low', 'low', '3', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1650 : ['low', 'low', '3', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1651 : ['low', 'low', '3', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1652 : ['low', 'low', '3', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1653 : ['low', 'low', '3', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1654 : ['low', 'low', '3', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1655 : ['low', 'low', '3', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1656 : ['low', 'low', '3', '4', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1657 : ['low', 'low', '3', '4', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1658 : ['low', 'low', '3', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1659 : ['low', 'low', '3', '4', 'med', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1660 : ['low', 'low', '3', '4', 'med', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1661 : ['low', 'low', '3', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1662 : ['low', 'low', '3', '4', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1663 : ['low', 'low', '3', '4', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1664 : ['low', 'low', '3', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1665 : ['low', 'low', '3', '5', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1666 : ['low', 'low', '3', '5', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1667 : ['low', 'low', '3', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1668 : ['low', 'low', '3', '5', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1669 : ['low', 'low', '3', '5', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1670 : ['low', 'low', '3', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1671 : ['low', 'low', '3', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1672 : ['low', 'low', '3', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1673 : ['low', 'low', '4', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1674 : ['low', 'low', '4', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1675 : ['low', 'low', '4', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1676 : ['low', 'low', '4', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1677 : ['low', 'low', '4', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1678 : ['low', 'low', '4', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1679 : ['low', 'low', '4', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1680 : ['low', 'low', '4', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1681 : ['low', 'low', '4', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1682 : ['low', 'low', '4', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1683 : ['low', 'low', '4', '4', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1684 : ['low', 'low', '4', '4', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1685 : ['low', 'low', '4', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1686 : ['low', 'low', '4', '4', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1687 : ['low', 'low', '4', '4', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1688 : ['low', 'low', '4', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1689 : ['low', 'low', '4', '4', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1690 : ['low', 'low', '4', '4', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1691 : ['low', 'low', '4', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1692 : ['low', 'low', '4', '5', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1693 : ['low', 'low', '4', '5', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1694 : ['low', 'low', '4', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1695 : ['low', 'low', '4', '5', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1696 : ['low', 'low', '4', '5', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1697 : ['low', 'low', '4', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1698 : ['low', 'low', '4', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1699 : ['low', 'low', '4', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1700 : ['low', 'low', '5', '2', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1701 : ['low', 'low', '5', '2', 'small', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1702 : ['low', 'low', '5', '2', 'small', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1703 : ['low', 'low', '5', '2', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1704 : ['low', 'low', '5', '2', 'med', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1705 : ['low', 'low', '5', '2', 'med', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1706 : ['low', 'low', '5', '2', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1707 : ['low', 'low', '5', '2', 'big', 'med', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1708 : ['low', 'low', '5', '2', 'big', 'high', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1709 : ['low', 'low', '5', '4', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1710 : ['low', 'low', '5', '4', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1711 : ['low', 'low', '5', '4', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1712 : ['low', 'low', '5', '4', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1713 : ['low', 'low', '5', '4', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1714 : ['low', 'low', '5', '4', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1715 : ['low', 'low', '5', '4', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1716 : ['low', 'low', '5', '4', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1717 : ['low', 'low', '5', '4', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1718 : ['low', 'low', '5', '5', 'small', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1719 : ['low', 'low', '5', '5', 'small', 'med', 'acc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1720 : ['low', 'low', '5', '5', 'small', 'high', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1721 : ['low', 'low', '5', '5', 'med', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1722 : ['low', 'low', '5', '5', 'med', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1723 : ['low', 'low', '5', '5', 'med', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1724 : ['low', 'low', '5', '5', 'big', 'low', 'unacc']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1725 : ['low', 'low', '5', '5', 'big', 'med', 'good']
# Negative example - ignored
# Current hypothesis: None
#
# Example 1726 : ['low', 'low', '5', '5', 'big', 'high', 'vgood']
# Negative example - ignored
# Current hypothesis: None
#
# Final Hypothesis:
# None
